# %% [markdown]
# # 1. Lib(Pandas)

# %%
# importing pandas as pd
import pandas as pd

# %%
# Creating a series with the use pandas
# and series is one dimension

names = pd.Series(['Kartik','Ayush','Surendra Pathare','Amruta Chadan Patade'])
names
# Out:
# 0                  Kartik
# 1                   Ayush
# 2        Surendra Pathare
# 3    Amruta Chadan Patade
# dtype: object

# %%
occupation= pd.Series(['Data Scienctiest','Web Developer','Programmer'])
occupation
# Out:
# 0    Data Scienctiest
# 1       Web Developer
# 2          Programmer
# dtype: object

# %%
info_table=pd.DataFrame({'Names':names,'Occupation':occupation})
info_table
# Out:
#                   Names        Occupation
# 0                Kartik  Data Scienctiest
# 1                 Ayush     Web Developer
# 2      Surendra Pathare        Programmer
# 3  Amruta Chadan Patade               NaN

# %%
# lets import some csv files using pandas
# we are reading our csv file using pandas # csv-------> comma seperated value

data = pd.read_csv(r'H:\Hotel Reservations.csv')
data
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
data.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %%
# This will give us an overview of our column and its data types;
data.dtypes
# Out:
# Booking_ID                               object
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                        object
# required_car_parking_space                int64
# room_type_reserved                       object
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                      object
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                           object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %%
data['Booking_ID']
# Out:
# 0        INN00001
# 1        INN00002
# 2        INN00003
# 3        INN00004
# 4        INN00005
#            ...
# 36270    INN36271
# 36271    INN36272
# 36272    INN36273
# 36273    INN36274
# 36274    INN36275
# Name: Booking_ID, Length: 36275, dtype: object

# %%
len(data)
# Out:
# 36275

# %%
data.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
data.head(11)
# Out:
#    Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0    INN00001             2               0                     1
# 1    INN00002             2               0                     2
# 2    INN00003             1               0                     2
# 3    INN00004             2               0                     0
# 4    INN00005             2               0                     1
# 5    INN00006             2               0                     0
# 6    INN00007             2               0                     1
# 7    INN00008             2               0                     1
# 8    INN00009             3               0                     0
# 9    INN00010             2               0                     0
# 10   INN00011             1               0                     1
#
#     no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                   2       Meal Plan 1                           0
# ...

# %%
data.tail()
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 36270                  6       Meal Plan 1                           0
# 36271                  3       Meal Plan 1                           0
# 36272                  6       Meal Plan 1                           0
# 36273                  3      Not Selected                           0
# 36274                  2       Meal Plan 1                           0
#
#       room_type_reserved  lead_time  arrival_year  arrival_month  \
# ...

# %%
data.tail(11)
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 36264   INN36265             2               0                     0
# 36265   INN36266             2               0                     1
# 36266   INN36267             2               0                     2
# 36267   INN36268             2               0                     1
# 36268   INN36269             1               0                     0
# 36269   INN36270             2               2                     0
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
# Getting rows with the use of index.
# using loc this will return the index 3 row.
data.loc[3]
# Out:
# Booking_ID                                 INN00004
# no_of_adults                                      2
# no_of_children                                    0
# no_of_weekend_nights                              0
# no_of_week_nights                                 2
# type_of_meal_plan                       Meal Plan 1
# required_car_parking_space                        0
# room_type_reserved                      Room_Type 1
# lead_time                                       211
# arrival_year                                   2018
# arrival_month                                     5
# arrival_date                                     20
# market_segment_type                          Online
# repeated_guest                                    0
# no_of_previous_cancellations                      0
# no_of_previous_bookings_not_canceled              0
# avg_price_per_room                            100.0
# no_of_special_requests                            0
# ...

# %%
data.loc[1]
# Out:
# Booking_ID                                  INN00002
# no_of_adults                                       2
# no_of_children                                     0
# no_of_weekend_nights                               2
# no_of_week_nights                                  3
# type_of_meal_plan                       Not Selected
# required_car_parking_space                         0
# room_type_reserved                       Room_Type 1
# lead_time                                          5
# arrival_year                                    2018
# arrival_month                                     11
# arrival_date                                       6
# market_segment_type                           Online
# repeated_guest                                     0
# no_of_previous_cancellations                       0
# no_of_previous_bookings_not_canceled               0
# avg_price_per_room                            106.68
# no_of_special_requests                             1
# ...

# %%
data['Booking_ID']=='INN00003'
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 36270    False
# 36271    False
# 36272    False
# 36273    False
# 36274    False
# Name: Booking_ID, Length: 36275, dtype: bool

# %%
data['type_of_meal_plan'].str.lower()
# Out:
# 0         meal plan 1
# 1        not selected
# 2         meal plan 1
# 3         meal plan 1
# 4        not selected
#              ...
# 36270     meal plan 1
# 36271     meal plan 1
# 36272     meal plan 1
# 36273    not selected
# 36274     meal plan 1
# Name: type_of_meal_plan, Length: 36275, dtype: object

# %%
data['Booking_ID']=='INN00003'
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 36270    False
# 36271    False
# 36272    False
# 36273    False
# 36274    False
# Name: Booking_ID, Length: 36275, dtype: bool
